# %%
import pandas as pd

# %%
population_data = pd.read_csv(r"C:\Users\Administrator\Downloads\archive (1)\world_population.csv")

# %%
population_data
# Out:
#      Rank CCA3  Country/Territory           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0           41128771         38972230         33753499         28189672
# 1            2842321          2866849          2882481          2913399
# ...

# %%
population_data.shape
## this shows you the number of rows and columns in your datasets
# Out:
# (234, 17)

# %%
population_data.head()
## this returns the first 5 rows in your datasets
# Out:
#    Rank CCA3 Country/Territory           Capital Continent  2022 Population  \
# 0    36  AFG       Afghanistan             Kabul      Asia         41128771
# 1   138  ALB           Albania            Tirana    Europe          2842321
# 2    34  DZA           Algeria           Algiers    Africa         44903225
# 3   213  ASM    American Samoa         Pago Pago   Oceania            44273
# 4   203  AND           Andorra  Andorra la Vella    Europe            79824
#
#    2020 Population  2015 Population  2010 Population  2000 Population  \
# 0         38972230         33753499         28189672         19542982
# 1          2866849          2882481          2913399          3182021
# 2         43451666         39543154         35856344         30774621
# 3            46189            51368            54849            58230
# 4            77700            71746            71519            66097
#
#    1990 Population  1980 Population  1970 Population  Area (km²)  \
# ...

# %%
population_data.tail()
## this returns the last 5 rows in your datasets
# Out:
#      Rank CCA3  Country/Territory   Capital Continent  2022 Population  \
# 229   226  WLF  Wallis and Futuna  Mata-Utu   Oceania            11572
# 230   172  ESH     Western Sahara  El Aaiún    Africa           575986
# 231    46  YEM              Yemen     Sanaa      Asia         33696614
# 232    63  ZMB             Zambia    Lusaka    Africa         20017675
# 233    74  ZWE           Zimbabwe    Harare    Africa         16320537
#
#      2020 Population  2015 Population  2010 Population  2000 Population  \
# 229            11655            12182            13142            14723
# 230           556048           491824           413296           270375
# 231         32284046         28516545         24743946         18628700
# 232         18927715         16248230         13792086          9891136
# 233         15669666         14154937         12839771         11834676
#
#      1990 Population  1980 Population  1970 Population  Area (km²)  \
# ...

# %%
population_data.sample(5)
## this returns 5 different random selection of rows o
# Out:
#      Rank CCA3       Country/Territory         Capital      Continent  \
# 28    221  VGB  British Virgin Islands       Road Town  North America
# 87     82  HTI                   Haiti  Port-au-Prince  North America
# 14    176  BHS                 Bahamas          Nassau  North America
# 13     91  AZE              Azerbaijan            Baku           Asia
# 157   222  PLW                   Palau       Ngerulmud        Oceania
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 28             31305            30910            29366            27556
# 87          11584996         11306801         10563757          9842880
# 14            409984           406471           392697           373272
# 13          10358074         10284951          9863480          9237202
# 157            18055            17972            17794            18540
#
#      2000 Population  1990 Population  1980 Population  1970 Population  \
# ...

# %%
population_data.index
# Out:
# RangeIndex(start=0, stop=234, step=1)

# %%
population_data.info()
## gives an overview of your datasets
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Rank                         234 non-null    int64
#  1   CCA3                         234 non-null    object
#  2   Country/Territory            234 non-null    object
#  3   Capital                      234 non-null    object
#  4   Continent                    234 non-null    object
#  5   2022 Population              234 non-null    int64
#  6   2020 Population              234 non-null    int64
#  7   2015 Population              234 non-null    int64
#  8   2010 Population              234 non-null    int64
#  9   2000 Population              234 non-null    int64
#  10  1990 Population              234 non-null    int64
#  11  1980 Population              234 non-null    int64
#  12  1970 Population              234 non-null    int64
# ...

# %%
population_data.values
# Out:
# array([[36, 'AFG', 'Afghanistan', ..., 63.0587, 1.0257, 0.52],
#        [138, 'ALB', 'Albania', ..., 98.8702, 0.9957, 0.04],
#        [34, 'DZA', 'Algeria', ..., 18.8531, 1.0164, 0.56],
#        ...,
#        [46, 'YEM', 'Yemen', ..., 63.8232, 1.0217, 0.42],
#        [63, 'ZMB', 'Zambia', ..., 26.5976, 1.028, 0.25],
#        [74, 'ZWE', 'Zimbabwe', ..., 41.7665, 1.0204, 0.2]], dtype=object)

# %%
population_data.isna().sum()
# this checks for missing values in your datasets
# Out:
# Rank                           0
# CCA3                           0
# Country/Territory              0
# Capital                        0
# Continent                      0
# 2022 Population                0
# 2020 Population                0
# 2015 Population                0
# 2010 Population                0
# 2000 Population                0
# 1990 Population                0
# 1980 Population                0
# 1970 Population                0
# Area (km²)                     0
# Density (per km²)              0
# Growth Rate                    0
# World Population Percentage    0
# dtype: int64

# %%
population_data.duplicated().sum()
# checks for duplicate values present in your datasets
# Out:
# 0

# %%
population_data.describe()
# this returns the statistical summary of your numerical data in your datasets
# Out:
#              Rank  2022 Population  2020 Population  2015 Population  \
# count  234.000000     2.340000e+02     2.340000e+02     2.340000e+02
# mean   117.500000     3.407441e+07     3.350107e+07     3.172996e+07
# std     67.694165     1.367664e+08     1.355899e+08     1.304050e+08
# min      1.000000     5.100000e+02     5.200000e+02     5.640000e+02
# 25%     59.250000     4.197385e+05     4.152845e+05     4.046760e+05
# 50%    117.500000     5.559944e+06     5.493074e+06     5.307400e+06
# 75%    175.750000     2.247650e+07     2.144798e+07     1.973085e+07
# max    234.000000     1.425887e+09     1.424930e+09     1.393715e+09
#
#        2010 Population  2000 Population  1990 Population  1980 Population  \
# count     2.340000e+02     2.340000e+02     2.340000e+02     2.340000e+02
# mean      2.984524e+07     2.626947e+07     2.271022e+07     1.898462e+07
# std       1.242185e+08     1.116982e+08     9.783217e+07     8.178519e+07
# ...

# %%
population_data[["Country/Territory", "Capital", "Continent", "2022 Population"]]
# Out:
#      Country/Territory           Capital Continent  2022 Population
# 0          Afghanistan             Kabul      Asia         41128771
# 1              Albania            Tirana    Europe          2842321
# 2              Algeria           Algiers    Africa         44903225
# 3       American Samoa         Pago Pago   Oceania            44273
# 4              Andorra  Andorra la Vella    Europe            79824
# ..                 ...               ...       ...              ...
# 229  Wallis and Futuna          Mata-Utu   Oceania            11572
# 230     Western Sahara          El Aaiún    Africa           575986
# 231              Yemen             Sanaa      Asia         33696614
# 232             Zambia            Lusaka    Africa         20017675
# 233           Zimbabwe            Harare    Africa         16320537
#
# [234 rows x 4 columns]

# %%
population_data.iloc[:10, 2]
# Out:
# 0            Afghanistan
# 1                Albania
# 2                Algeria
# 3         American Samoa
# 4                Andorra
# 5                 Angola
# 6               Anguilla
# 7    Antigua and Barbuda
# 8              Argentina
# 9                Armenia
# Name: Country/Territory, dtype: object

# %%
population_data.sort_values(by="Rank", inplace=True)

# %%
population_data.head()
# Out:
#      Rank CCA3 Country/Territory           Capital      Continent  \
# 41      1  CHN             China           Beijing           Asia
# 92      2  IND             India         New Delhi           Asia
# 221     3  USA     United States  Washington, D.C.  North America
# 93      4  IDN         Indonesia           Jakarta           Asia
# 156     5  PAK          Pakistan         Islamabad           Asia
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 41        1425887337       1424929781       1393715448       1348191368
# 92        1417173173       1396387127       1322866505       1240613620
# 221        338289857        335942003        324607776        311182845
# 93         275501339        271857970        259091970        244016173
# 156        235824862        227196741        210969298        194454498
#
#      2000 Population  1990 Population  1980 Population  1970 Population  \
# ...

# %%
population_data.iloc[:10,2]
# Out:
# 41             China
# 92             India
# 221    United States
# 93         Indonesia
# 156         Pakistan
# 149          Nigeria
# 27            Brazil
# 16        Bangladesh
# 171           Russia
# 131           Mexico
# Name: Country/Territory, dtype: object

# %%
top_10_most_populus = population_data[["Rank", "Country/Territory", "2022 Population"]][:10]

# %%
top_10_most_populus
# Out:
#      Rank Country/Territory  2022 Population
# 41      1             China       1425887337
# 92      2             India       1417173173
# 221     3     United States        338289857
# 93      4         Indonesia        275501339
# 156     5          Pakistan        235824862
# 149     6           Nigeria        218541212
# 27      7            Brazil        215313498
# 16      8        Bangladesh        171186372
# 171     9            Russia        144713314
# 131    10            Mexico        127504125

# %%
#population_data["2020_density"] = population_data["2020 Population"] / population_data["Area(Km²)"]

# %%
population_data["Continent"].value_counts()
# Out:
# Continent
# Africa           57
# Asia             50
# Europe           50
# North America    40
# Oceania          23
# South America    14
# Name: count, dtype: int64

# %%
continents_list = list(population_data["Continent"].unique())

# %%
population_data_over_500million = population_data[population_data["2022 Population"] > 500000000]

# %%
population_data_over_500million
# Out:
#     Rank CCA3 Country/Territory    Capital Continent  2022 Population  \
# 41     1  CHN             China    Beijing      Asia       1425887337
# 92     2  IND             India  New Delhi      Asia       1417173173
#
#     2020 Population  2015 Population  2010 Population  2000 Population  \
# 41       1424929781       1393715448       1348191368       1264099069
# 92       1396387127       1322866505       1240613620       1059633675
#
#     1990 Population  1980 Population  1970 Population  Area (km²)  \
# 41       1153704252        982372466        822534450     9706961
# 92        870452165        696828385        557501301     3287590
#
#     Density (per km²)  Growth Rate  World Population Percentage
# 41           146.8933       1.0000                        17.88
# 92           431.0675       1.0068                        17.77

# %%
population_data_over_100million = population_data[population_data["2022 Population"] > 100000000]

# %%
population_data_over_100million
# Out:
#      Rank CCA3 Country/Territory           Capital      Continent  \
# 41      1  CHN             China           Beijing           Asia
# 92      2  IND             India         New Delhi           Asia
# 221     3  USA     United States  Washington, D.C.  North America
# 93      4  IDN         Indonesia           Jakarta           Asia
# 156     5  PAK          Pakistan         Islamabad           Asia
# 149     6  NGA           Nigeria             Abuja         Africa
# 27      7  BRA            Brazil          Brasilia  South America
# 16      8  BGD        Bangladesh             Dhaka           Asia
# 171     9  RUS            Russia            Moscow         Europe
# 131    10  MEX            Mexico       Mexico City  North America
# 102    11  JPN             Japan             Tokyo           Asia
# 63     12  ETH          Ethiopia       Addis Ababa         Africa
# 163    13  PHL       Philippines            Manila           Asia
# ...

# %%
population_data_over_100million.shape
# Out:
# (14, 17)

# %%
number_of_counts_100million = population_data_over_100million.shape

# %%
number_of_counts_100million[0]
# Out:
# 14

# %%
number_of_counts_100million_africa = population_data[(population_data["2022 Population"] > 100000000) & (population_data["Continent"] == "Africa")]

# %%
number_of_counts_100million_africa
# Out:
#      Rank CCA3 Country/Territory      Capital Continent  2022 Population  \
# 149     6  NGA           Nigeria        Abuja    Africa        218541212
# 63     12  ETH          Ethiopia  Addis Ababa    Africa        123379924
# 57     14  EGY             Egypt        Cairo    Africa        110990103
#
#      2020 Population  2015 Population  2010 Population  2000 Population  \
# 149        208327405        183995785        160952853        122851984
# 63         117190911        102471895         89237791         67031867
# 57         107465134         97723799         87252413         71371371
#
#      1990 Population  1980 Population  1970 Population  Area (km²)  \
# 149         95214257         72951439         55569264      923768
# 63          47878073         34945469         28308246     1104300
# 57          57214630         43748556         34781986     1002450
#
#      Density (per km²)  Growth Rate  World Population Percentage
# ...
